# %% [markdown]
# ## Questions

# %% [markdown]
# 1. Does increasing the number of "times" we "train" the data, cause --> Overfitting?
#    - Follow up-> Is there something like the elbow method to choose the right number of times we train?
#
# 2. How do I visualize the changes that are being made during/while training?
#    - This can allow me to re-write the code? so that the model learns better from the data. Or Learns, what I want it to learn from the data

# %% [markdown]
# ## Notes

# %% [markdown]
# https://forums.fast.ai/t/lesson-2-official-topic/96033

# %% [markdown]
# ## Quizes

# %% [markdown]
# https://aiquizzes.com/knowledgebase

# %% [markdown]
# ## Lesson 1

# %% [markdown]
# weights = parameters

# %% [markdown]
# - The functional form of the *model* is called its *architecture* (but be careful—sometimes people use *model* as a synonym of *architecture*, so this can get confusing).
# - The *weights* are called *parameters*.
# - The *predictions* are calculated from the *independent variable*, which is the *data* not including the *labels*.
# - The *results* of the model are called *predictions*.
# - The measure of *performance* is called the *loss*.
# - The loss depends not only on the predictions, but also the correct *labels* (also known as *targets* or the *dependent variable*); e.g., "dog" or "cat."

# %% [markdown]
# A `Transform` contains code that is applied automatically during training

# %% [markdown]
# Types of `Transforms`

# %% [markdown]
# There are two kinds: `item_tfms` are applied to each item (in this case, each item is resized to a 224-pixel square), while `batch_tfms` are applied to a *batch* of items at a time using the GPU, so they're particularly fast (we'll see many examples of these throughout this book).

# %% [markdown]
# <b>What size to crop pictures to?

# %% [markdown]
# Why 224 pixels? This is the standard size for historical reasons (old pretrained models require this size exactly), but you can pass pretty much anything. If you increase the size, you'll often get a model with better results (since it will be able to focus on more details), but at the price of speed and memory consumption; the opposite is true if you decrease the size.

# %% [markdown]
# <b>Regression --> Predict Numeric Data || Classification --> Predict Categorical Data

# %% [markdown]
# > Note: Classification and Regression: _classification_ and _regression_ have very specific meanings in machine learning. These are the two main types of model that we will be investigating in this book. A classification model is one which attempts to predict a class, or category. That is, it's predicting from a number of discrete possibilities, such as "dog" or "cat." A regression model is one which attempts to predict one or more numeric quantities, such as a temperature or a location. **Sometimes people use the word _regression_ to refer to a particular kind of model called a _linear regression model_**; this is a **bad practice**, and we won't be using that terminology in this book!

# %% [markdown]
# `error_rate` --> % Error on Validation Set
# `acuracy` --> 1 - `error_rate`

# %% [markdown]
# <b> Pretrained Model

# %% [markdown]
# A model that has weights that have already been trained on some other dataset is called a pretrained model.

# %% [markdown]
# Transfer learning: Using a pretrained model for a task different to what it was originally trained for.

# %% [markdown]
# <b> Almost always USE a pretrained model

# %% [markdown]
# You should nearly always use a pretrained model, because it means that your model, before you've even shown it any of your data, is already very capable.

# %% [markdown]
# When using a pretrained model, vision_learner will remove the last layer, since that is always specifically customized to the original training task (i.e. ImageNet dataset classification), and replace it with one or more new layers with randomized weights, of an appropriate size for the dataset you are working with.

# %% [markdown]
# This is the last part of the model --> called ---> `head`

# %% [markdown]
# Using pretrained models is the most important method we have to allow us to train more accurate models, more quickly, with less data, and less time and money. You might think that would mean that using pretrained models would be the most studied area in academic deep learning... but you'd be very, very wrong! The importance of pretrained models is generally not recognized or discussed in most courses, books, or software library features, and is rarely considered in academic papers. As we write this at the start of 2020, things are just starting to change, but it's likely to take a while.

# %% [markdown]
# <b>People dont use `Pretrained`. So be careful while speaking to them!!

# %% [markdown]
# So be careful: most people you speak to will probably greatly underestimate what you can do in deep learning with few resources, because they probably won't deeply understand how to use pretrained models.

# %% [markdown]
# ## Lesson 2

# %% [markdown]
# https://www.tanishq.ai/blog/posts/2021-11-16-gradio-huggingface.html

# %% [markdown]
# ## Lesson 5

# %% [markdown]
# ### <b>A Cool trick with Pandas

# %% [markdown]
# <h4>Here is the <a href="https://youtu.be/_rXzeWq4C6w?list=PLfYUBJiXbdtSvpQjSnJJ_PmDQB_VyT5iU&t=527">timestamp</a>

# %% [markdown]
# ![image.png](attachment:dca20a72-2790-4da1-8b37-9fe9d99e8439.png)
